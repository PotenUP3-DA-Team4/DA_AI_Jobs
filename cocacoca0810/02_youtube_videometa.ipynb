# %%
import pandas as pd

# %%
df = pd.read_csv(
    ".\data\youtube_video_meta.csv"
)
df
# Out:
#        video_id                channel_id          published_at  \
# 0   k5O1F_IS0mU  UCzh4yY8rl38knH33XpNqXbQ  2023-12-21T17:36:37Z
# 1   rDFUl2mHIW4  UCzh4yY8rl38knH33XpNqXbQ  2023-08-18T09:00:08Z
# 2   fff8P0kYexQ  UCmblbE_WxTaFWcMEGFJ_97w  2025-11-06T09:00:02Z
# 3   T_gJpnjJsnk  UCe52oeb7Xv_KaJsEzcKXJJg  2023-03-18T06:51:01Z
# 4   EYG4ROejmyI  UCPZIPuQPrfrUG9Xe_okEmQA  2024-08-20T08:55:08Z
# 5   8L001YT4k6k  UCPZIPuQPrfrUG9Xe_okEmQA  2025-11-10T09:00:07Z
# 6   8L001YT4k6k  UCPZIPuQPrfrUG9Xe_okEmQA  2025-11-10T09:00:07Z
# 7   6ZUIwj3FgUY  UCYDmx2Sfpnaxg488yBpZIGg  2023-04-10T09:00:10Z
# 8   B1ShLiq3EVc  UCYDmx2Sfpnaxg488yBpZIGg  2025-08-25T09:00:05Z
# 9   3_b5oKGndn0  UCbD8EppRX3ZwJSou-TVo90A  2023-09-07T10:35:43Z
# 10  iUw3LPM7OBU  UCEf_Bc-KVd7onSeifS3py9g  2023-09-04T09:00:24Z
# 11  TVqEwvbZP30  UCEf_Bc-KVd7onSeifS3py9g  2025-11-24T09:00:03Z
#
#                                           video_title        channel_name  \
# ...
