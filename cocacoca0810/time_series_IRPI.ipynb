# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns 
import koreanize_matplotlib

# %%
df = pd.read_csv(
    "./data/02_raw/time_series_KR_20210101-0000_20260204-1645.csv"
)
df
# Out:
#           Time  플레이브  라이즈  이세계아이돌  IVE
# 0   2020-12-01     0    0       0    0
# 1   2021-01-01     0    0       0    0
# 2   2021-02-01     0    0       0    0
# 3   2021-03-01     0    0       0    0
# 4   2021-04-01     0    0       0    0
# ..         ...   ...  ...     ...  ...
# 57  2025-09-01    24   23      16   35
# 58  2025-10-01    16   22      17   31
# 59  2025-11-01    20   21      22   33
# 60  2025-12-01    13   18      12   28
# 61  2026-01-01    12   17      10   30
#
# [62 rows x 5 columns]

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 62 entries, 0 to 61
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Time    62 non-null     str
#  1   플레이브    62 non-null     int64
#  2   라이즈     62 non-null     int64
#  3   이세계아이돌  62 non-null     int64
#  4   IVE     62 non-null     int64
# dtypes: int64(4), str(1)
# memory usage: 2.6 KB

# %%
# dt로 변경
df["Time"] = pd.to_datetime(df["Time"])

# %%
# 그룹별로 묶기
df["2023"] = df["플레이브"] + df["라이즈"]
df["2021"] = df["이세계아이돌"] + df["IVE"]

# %%
# 검색 데이터가 0인 값 지우기
